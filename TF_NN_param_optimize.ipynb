# %%
import re
from time import time
from collections import Counter

import tensorflow as tf
import pandas as pd
import numpy as np

from nltk.stem.porter import PorterStemmer
from fastcache import clru_cache as lru_cache

from sklearn.model_selection import ShuffleSplit
from sklearn import metrics

from tqdm import tqdm, tqdm_notebook
tqdm.pandas(tqdm_notebook())
# Out:
# /home/mohsin/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# A Jupyter Widget

# %%
t_start = time()

stemmer = PorterStemmer()

def rmse(y_true, y_pred):
    return np.sqrt(metrics.mean_squared_error(y_true, y_pred))

@lru_cache(1024)
def stem(s):
    return stemmer.stem(s)

whitespace = re.compile(r'\s+')
non_letter = re.compile(r'\W+')

def tokenize(text):
    text = text.lower()
    text = non_letter.sub(' ', text)

    tokens = []

    for t in text.split():
        #t = stem(t)
        tokens.append(t)

    return tokens

class Tokenizer:
    def __init__(self, min_df=10, tokenizer=str.split):
        self.min_df = min_df
        self.tokenizer = tokenizer
        self.doc_freq = None
        self.vocab = None
        self.vocab_idx = None
        self.max_len = None

    def fit_transform(self, texts):
        tokenized = []
        doc_freq = Counter()
        n = len(texts)

        for text in texts:
            sentence = self.tokenizer(text)
            tokenized.append(sentence)
            doc_freq.update(set(sentence))

        vocab = sorted([t for (t, c) in doc_freq.items() if c >= self.min_df])
        vocab_idx = {t: (i + 1) for (i, t) in enumerate(vocab)}
        doc_freq = [doc_freq[t] for t in vocab]

        self.doc_freq = doc_freq
        self.vocab = vocab
        self.vocab_idx = vocab_idx

        max_len = 0
        result_list = []
        for text in tokenized:
            text = self.text_to_idx(text)
            max_len = max(max_len, len(text))
            result_list.append(text)

        self.max_len = max_len
        result = np.zeros(shape=(n, max_len), dtype=np.int32)
        for i in range(n):
            text = result_list[i]
            result[i, :len(text)] = text

        return result    

    def text_to_idx(self, tokenized):
        return [self.vocab_idx[t] for t in tokenized if t in self.vocab_idx]

    def transform(self, texts):
        n = len(texts)
        result = np.zeros(shape=(n, self.max_len), dtype=np.int32)

        for i in range(n):
            text = self.tokenizer(texts[i])
            text = self.text_to_idx(text)[:self.max_len]
            result[i, :len(text)] = text

        return result
    
    def vocabulary_size(self):
        return len(self.vocab) + 1

# %%
# %%time
print('reading train data...')
df_train = pd.read_csv('../input/train.tsv', sep='\t')
df_train = df_train[df_train.price != 0].reset_index(drop=True)

price = df_train.pop('price')
y = np.log1p(price.values).reshape(-1,1)
mean = y.mean()
std = y.std()
ynorm = (y - mean) / std
ynorm = ynorm.reshape(-1, 1)
# Out:
# reading train data...
# CPU times: user 4.3 s, sys: 278 ms, total: 4.58 s
# Wall time: 4.62 s

# %%
# %%time
df_train.name.fillna('unkname', inplace=True)
df_train.category_name.fillna('unk_cat', inplace=True)
df_train.brand_name.fillna('unk_brand', inplace=True)
df_train.item_description.fillna('nodesc', inplace=True)
# Out:
# CPU times: user 300 ms, sys: 836 µs, total: 301 ms
# Wall time: 299 ms

# %%
# %%time
#impute brand names using flashtext
def get_brands(x, keyword_processor):
    matches = keyword_processor.extract_keywords(' '.join(x))
    if len(matches) > 0:
        return matches[0]
    else:
        return None
    
from flashtext import KeywordProcessor
all_brands = df_train.loc[df_train.brand_name.value_counts().values > 1, 'brand_name'].tolist()
#all_brands.remove('always')

keyword_processor = KeywordProcessor(case_sensitive=True)
keyword_processor.add_keywords_from_list(all_brands)
print(len(keyword_processor))

tmp = df_train[['name','item_description']].progress_apply(lambda x: get_brands(x, keyword_processor), axis=1).fillna("unk_brand")
missing_indices = df_train['brand_name'] == 'unk_brand'
df_train.loc[missing_indices, 'brand_name'] = tmp[missing_indices]
df_train.brand_name.fillna("unk_brand", inplace=True)
# Out:
#   0%|          | 597/1481661 [00:00<04:08, 5967.08it/s]
# 448
# 100%|██████████| 1481661/1481661 [01:11<00:00, 20753.17it/s]
# CPU times: user 1min 11s, sys: 184 ms, total: 1min 12s
# Wall time: 1min 11s

# %%
# %%time
print('processing category...')

def paths(tokens):
    all_paths = ['/'.join(tokens[0:(i+1)]) for i in range(len(tokens))]
    return ' '.join(all_paths)

@lru_cache(1024)
def cat_process(cat):
    cat = cat.lower()
    cat = whitespace.sub('', cat)
    split = cat.split('/')
    return paths(split)

df_train.category_name = df_train.category_name.apply(cat_process)

cat_tok = Tokenizer(min_df=10)
X_cat = cat_tok.fit_transform(df_train.category_name)
cat_voc_size = cat_tok.vocabulary_size()
print(cat_voc_size)
# Out:
# processing category...
# 1129
# CPU times: user 10.3 s, sys: 160 ms, total: 10.4 s
# Wall time: 10.4 s

# %%
# %%time
print('processing title...')
name_num_col = 7
name_tok = Tokenizer(min_df=5, tokenizer=tokenize)
X_name = name_tok.fit_transform(df_train.name)
X_name = X_name[:, :name_num_col]
name_voc_size = name_tok.vocabulary_size()
print(name_voc_size)
# Out:
# processing title...
# 25587
# CPU times: user 15.4 s, sys: 216 ms, total: 15.6 s
# Wall time: 15.6 s

# %%
# %%time
print('processing description...')

desc_num_col = 40
desc_tok = Tokenizer(min_df=10, tokenizer=tokenize)
X_desc = desc_tok.fit_transform(df_train.item_description)
X_desc = X_desc[:, :desc_num_col]
desc_voc_size = desc_tok.vocabulary_size()
print(desc_voc_size)
# Out:
# processing description...
# 32139
# CPU times: user 47.6 s, sys: 908 ms, total: 48.5 s
# Wall time: 48.5 s

# %%
# %%time
print('processing brand...')

df_train.brand_name = df_train.brand_name.str.lower()
df_train.brand_name = df_train.brand_name.str.replace(' ', '_')

brand_cnt = Counter(df_train.brand_name[df_train.brand_name != 'unk_brand'])
brands = sorted(b for (b, c) in brand_cnt.items() if c >= 2)
brands_idx = {b: (i + 1) for (i, b) in enumerate(brands)}

X_brand = df_train.brand_name.apply(lambda b: brands_idx.get(b, 0))
X_brand = X_brand.values.reshape(-1, 1) 
brand_voc_size = len(brands) + 1
print(brand_voc_size)
# Out:
# processing brand...
# 3567
# CPU times: user 1.62 s, sys: 12 ms, total: 1.63 s
# Wall time: 1.63 s

# %%
# %%time
print('processing other features...')

X_item_cond = (df_train.item_condition_id - 1).astype('uint8').values.reshape(-1, 1)
X_shipping = df_train.shipping.astype('float32').values.reshape(-1, 1)
# Out:
# processing other features...
# CPU times: user 17.2 ms, sys: 40.2 ms, total: 57.4 ms
# Wall time: 91.5 ms

# %%
# %%time
print("getting count features")

X_name_wcount = df_train.item_description.apply(lambda x: len(str(x).split()))
X_name_wcount = X_name_wcount.values.reshape(-1,1)/X_name_wcount.max()
# Out:
# getting count features
# CPU times: user 2.45 s, sys: 40.1 ms, total: 2.49 s
# Wall time: 2.49 s

# %%
print('defining the model...')

def prepare_batches(seq, step):
    n = len(seq)
    res = []
    for i in range(0, n, step):
        res.append(seq[i:i+step])
    return res

def conv1d(inputs, num_filters, filter_size, padding='same'):
    he_std = np.sqrt(2 / (filter_size * num_filters))
    out = tf.layers.conv1d(
        inputs=inputs, filters=num_filters, padding=padding,
        kernel_size=filter_size,
        activation=tf.nn.relu, 
        kernel_initializer=tf.random_normal_initializer(stddev=he_std))
    return out

def dense(X, size, reg=0.0, activation=None):
    he_std = np.sqrt(2 / int(X.shape[1]))
    out = tf.layers.dense(X, units=size, activation=activation, 
                     kernel_initializer=tf.random_normal_initializer(stddev=he_std),
                     #kernel_regularizer=tf.contrib.layers.l2_regularizer(reg)
                         )
    return out

def embed(inputs, size, dim):
    std = np.sqrt(2 / dim)
    emb = tf.Variable(tf.random_uniform([size, dim], -std, std))
    lookup = tf.nn.embedding_lookup(emb, inputs)
    return lookup
# Out:
# defining the model...

# %%
def train_tf(params):

    name_embed, desc_embed, brand_embed, cat_embed, dense1_dim, dense2_dim, lr1, lr2, lr3,\
            name_drop, desc_drop, dense_drop, name_filters3, name_filters2, desc_filter3, desc_filter2, batch_size = params
     
    ypreds = []
    ytrues = []
    for k, randint in enumerate(np.random.choice(1000, 4)):
        
        name_embeddings_dim = name_embed
        name_seq_len = X_name.shape[1]
        desc_embeddings_dim = desc_embed
        desc_seq_len = X_desc.shape[1]

        brand_embeddings_dim = brand_embed

        cat_embeddings_dim = cat_embed
        cat_seq_len = X_cat.shape[1]


        graph = tf.Graph()
        graph.seed = 1

        with graph.as_default():
            place_name = tf.placeholder(tf.int32, shape=(None, name_seq_len))
            place_desc = tf.placeholder(tf.int32, shape=(None, desc_seq_len))
            place_brand = tf.placeholder(tf.int32, shape=(None, 1))
            place_cat = tf.placeholder(tf.int32, shape=(None, cat_seq_len))
            place_ship = tf.placeholder(tf.float32, shape=(None, 1))
            place_cond = tf.placeholder(tf.uint8, shape=(None, 1))
            #place_wcount = tf.placeholder(tf.float32, shape=(None, 1))
            prob_name = tf.placeholder_with_default(0.0, shape=())
            prob_desc = tf.placeholder_with_default(0.0, shape=())
            prob_dense = tf.placeholder_with_default(0.0, shape=())

            place_y = tf.placeholder(dtype=tf.float32, shape=(None, 1))

            place_lr = tf.placeholder(tf.float32, shape=(), )

            name = embed(place_name, name_voc_size, name_embeddings_dim)
            desc = embed(place_desc, desc_voc_size, desc_embeddings_dim)
            brand = embed(place_brand, brand_voc_size, brand_embeddings_dim)
            cat = embed(place_cat, cat_voc_size, cat_embeddings_dim)


            name = tf.layers.average_pooling1d(name, pool_size=int(name_seq_len), strides=1, padding='valid')
            name = tf.layers.dropout(name, rate=prob_name, seed=1, training=True)
            name = tf.contrib.layers.flatten(name)
            #print(name.shape)

            desc = tf.layers.average_pooling1d(desc, pool_size=int(desc_seq_len), strides=1, padding='valid')
            desc = tf.layers.dropout(desc, rate=prob_desc, seed=1, training=True)
            desc = tf.contrib.layers.flatten(desc)
            #print(desc.shape)

            brand = tf.contrib.layers.flatten(brand)
            #print(brand.shape)

            cat = tf.layers.average_pooling1d(cat, pool_size=cat_seq_len, strides=1, padding='valid')
            cat = tf.contrib.layers.flatten(cat)
            #print(cat.shape)

            ship = place_ship
            #print(ship.shape)

            #name_wcount = place_wcount
            #print(name_wcount.shape)

            cond = tf.one_hot(place_cond, 5)
            cond = tf.contrib.layers.flatten(cond)
            #print(cond.shape)

            out = tf.concat([name, desc, brand, cat, ship, cond], axis=1)
            #print('concatenated dim:', out.shape)
            #out = tf.contrib.layers.batch_norm(out, decay=0.9)
            out = dense(out, dense1_dim, activation=tf.nn.relu)
            out = tf.contrib.nn.alpha_dropout(out, keep_prob=1 - prob_dense, seed=1)
            
            out = dense(out, dense2_dim, activation=tf.nn.relu)
            out = tf.contrib.nn.alpha_dropout(out, keep_prob=1 -prob_dense, seed=1)

            out = dense(out, 1)

            loss = tf.losses.mean_squared_error(place_y, out)
            rmse = tf.sqrt(loss)
            opt = tf.train.AdamOptimizer(learning_rate=place_lr)
            train_step = opt.minimize(loss)

            init = tf.global_variables_initializer()

        session = tf.Session(config=None, graph=graph)
        session.run(init)
        ##### print('training the model...')
        ypreds2 = []
        train_idx, val_idx= list(ShuffleSplit(1, test_size=0.05, random_state=randint).split(X_name))[0]
        lr_init=lr1
        lr_decay=0.0014
        lr = lr_init
        for i in range(3):
            t0 = time()
            np.random.seed(i)
            np.random.shuffle(train_idx)
            batches = prepare_batches(train_idx, batch_size)

            if i == 1:
                lr = lr2# 0.001
            elif i == 2:
                lr = lr3 # 0.001/0.0005
            elif i == 3:
                lr = 0.00001 # 1e-6
            #lr = lr_init - lr_decay*i
            print("current learning rate", lr)
            for j, idx in enumerate(batches):
                #if i == 0:
                #    lr = lr_init - 0.002*j/(len(batches)-1)
                feed_dict = {
                    place_name: X_name[idx],
                    place_desc: X_desc[idx],
                    place_brand: X_brand[idx],
                    place_cat: X_cat[idx],
                    place_cond: X_item_cond[idx],
                    place_ship: X_shipping[idx],
                    prob_name: name_drop,
                    prob_desc: desc_drop,
                    prob_dense: dense_drop,
                    #place_wcount: X_name_wcount[idx],
                    place_y: ynorm[idx],
                    place_lr: lr,
                }
                session.run(train_step, feed_dict=feed_dict)

            took = time() - t0
            print('Training epoch %d took %.3fs' % (i, took))
            val_batches = prepare_batches(val_idx, 5000)
            y_pred = np.zeros(len(X_name))
            for idx in val_batches:
                feed_dict = {
                    place_name: X_name[idx],
                    place_desc: X_desc[idx],
                    place_brand: X_brand[idx],
                    place_cat: X_cat[idx],
                    place_cond: X_item_cond[idx],
                    place_ship: X_shipping[idx],
                    prob_name: 0.0,
                    prob_desc: 0.0,
                    prob_dense: 0.0,
                    #place_wcount: X_name_wcount[idx],
                }
                batch_pred = session.run(out, feed_dict=feed_dict)
                y_pred[idx] = batch_pred[:, 0]
            y_pred_val = (y_pred[val_idx])*std + mean
            ypreds2.append(y_pred_val)
            y_true_val = (ynorm[val_idx][:,0])*std + mean
            score = np.sqrt(metrics.mean_squared_error(y_true_val, y_pred_val))
            print("Validation rmse for {}th set {} epoch is {}".format(k, i, score))
            
        y_pred_mean = ypreds2[0]*0.1 + ypreds2[1]*0.4 + ypreds2[2]*0.5
        score = np.sqrt(metrics.mean_squared_error(y_true_val, y_pred_mean))
        ypreds.extend(y_pred_mean)
        ytrues.extend(y_true_val)
        print("Validation rmse for {}th set is {}".format(k, score))
    overall_score = np.sqrt(metrics.mean_squared_error(ytrues, ypreds))
    print("Overall Validation rmse for {} is {}".format(params, overall_score))
    print(" ")
    print(" ")
    
    return overall_score

# %%
##### print('training the model...')
params = [100, 100, 40, 30, 300, 150, 0.003, 0.002, 0.001, 0.05, 0.1, 0.0, 20, 20, 20, 20, 2000]
train_tf(params)
# Out:
# current learning rate 0.003
# Training epoch 0 took 7.201s
# Validation rmse for 0th set 0 epoch is 0.43410001078931576
# current learning rate 0.002
# Training epoch 1 took 7.340s
# Validation rmse for 0th set 1 epoch is 0.4222762194606952
# current learning rate 0.001
# Training epoch 2 took 7.256s
# Validation rmse for 0th set 2 epoch is 0.41833763398772333
# Validation rmse for 0th set is 0.41618030795377964
# current learning rate 0.003
# Training epoch 0 took 7.277s
# Validation rmse for 1th set 0 epoch is 0.4376433553070137
# current learning rate 0.002
# Training epoch 1 took 7.245s
# Validation rmse for 1th set 1 epoch is 0.423218415542139
# current learning rate 0.001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-a1615ccba34e> in <module>()
#       1 ##### print('training the model...')
#       2 params = [100, 100, 40, 30, 300, 150, 0.003, 0.002, 0.001, 0.05, 0.1, 0.0, 20, 20, 20, 20, 2000]
# ----> 3 train_tf(params)
#
# <ipython-input-50-882f96e4aec6> in train_tf(params)
#     127                     place_lr: lr,
#     128                 }
# --> 129                 session.run(train_step, feed_dict=feed_dict)
#     130
#     131             took = time() - t0
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import skopt
from skopt import gp_minimize, gbrt_minimize
from skopt.space import Real, Integer, Categorical

# %%
space = [Integer(16, 512), #name='name_embed'),
         Integer(16, 512),# name='desc_embed'),
         Integer(16, 256),# name='brand_embed'),
         Integer(16, 256),# name='cat_embed'),
         Integer(64, 512),# name='dense1_dim'),
         Integer(32, 256),# name='dense2_dim'),
         Real(0.001, 0.01, "uniform"), #name='lr1'),
         Real(1e-5, 0.005, "uniform"), #name='lr2'),
         Real(1e-5, 1e-3, "log-uniform"), #name='lr3'),
         Real(0.001, 0.4, "uniform"), #name='name_drop'),
         Real(0.001, 0.5, "uniform"), #name='desc_drop'),
         Real(0.0, 0.05, "uniform"), #name='dense_drop'),
         Integer(10, 30), #name='name_filters3'),
         Integer(10, 30), #name='name_filters2'),
         Integer(10, 30), #name='desc_filters3'),
         Integer(10, 30), #name='desc_filters2'),
         Integer(256, 5000), #name='batch_size'),
        ]

res_gp = gbrt_minimize(train_tf, space, n_calls=100, random_state=0)
# Out:
# current learning rate 0.008625265649057131
# Training epoch 0 took 6.590s
# Validation rmse for 0th set 0 epoch is 0.4434127747140635
# current learning rate 0.003121582846962003
# Training epoch 1 took 6.555s
# Validation rmse for 0th set 1 epoch is 0.43216031750481443
# current learning rate 5.871694001325899e-05
# Training epoch 2 took 6.503s
# Validation rmse for 0th set 2 epoch is 0.4324635647097395
# Validation rmse for 0th set is 0.4317298305791089
# current learning rate 0.008625265649057131
# Training epoch 0 took 6.513s
# Validation rmse for 1th set 0 epoch is 0.4422179442534868
# current learning rate 0.003121582846962003
# Training epoch 1 took 6.627s
# Validation rmse for 1th set 1 epoch is 0.43171878452698687
# current learning rate 5.871694001325899e-05
# Training epoch 2 took 6.513s
# Validation rmse for 1th set 2 epoch is 0.43059525116511915
# Validation rmse for 1th set is 0.4306897288078303
# current learning rate 0.008625265649057131
# Training epoch 0 took 6.589s
# Validation rmse for 2th set 0 epoch is 0.44707113556983463
# current learning rate 0.003121582846962003
# Training epoch 1 took 6.773s
# Validation rmse for 2th set 1 epoch is 0.4307368265422923
# current learning rate 5.871694001325899e-05
# Training epoch 2 took 6.558s
# Validation rmse for 2th set 2 epoch is 0.4305695746260202
# Validation rmse for 2th set is 0.4305673752995133
# current learning rate 0.008625265649057131
# Training epoch 0 took 6.685s
# Validation rmse for 3th set 0 epoch is 0.4438228575313837
# current learning rate 0.003121582846962003
# Training epoch 1 took 6.568s
# Validation rmse for 3th set 1 epoch is 0.4332701265041305
# current learning rate 5.871694001325899e-05
# Training epoch 2 took 6.956s
# Validation rmse for 3th set 2 epoch is 0.4321721737295134
# Validation rmse for 3th set is 0.4322660680289343
# Overall Validation rmse for [188, 63, 133, 208, 387, 227, 0.008625265649057131, 0.003121582846962003, 5.871694001325899e-05, 0.11971630801124446, 0.029299775681404152, 0.013632814729005663, 11, 16, 17, 24, 3153] is 0.4313138379863136
#
#
# current learning rate 0.0011819655769629315
# Training epoch 0 took 11.580s
# Validation rmse for 0th set 0 epoch is 0.4647259005502851
# current learning rate 0.004164773029284211
# Training epoch 1 took 11.506s
# Validation rmse for 0th set 1 epoch is 0.5117226323691885
# current learning rate 0.0003600091192911613
# Training epoch 2 took 11.641s
# Validation rmse for 0th set 2 epoch is 0.44559696733423576
# Validation rmse for 0th set is 0.4625733687940837
# current learning rate 0.0011819655769629315
# Training epoch 0 took 11.587s
# Validation rmse for 1th set 0 epoch is 0.46021986178446966
# current learning rate 0.004164773029284211
# Training epoch 1 took 11.548s
# Validation rmse for 1th set 1 epoch is 0.48551502225377047
# current learning rate 0.0003600091192911613
# Training epoch 2 took 11.549s
# Validation rmse for 1th set 2 epoch is 0.4495826508955704
# Validation rmse for 1th set is 0.45835236571465793
# current learning rate 0.0011819655769629315
# Training epoch 0 took 11.632s
# Validation rmse for 2th set 0 epoch is 0.4540329079302774
# current learning rate 0.004164773029284211
# Training epoch 1 took 11.620s
# Validation rmse for 2th set 1 epoch is 0.4408477707063876
# current learning rate 0.0003600091192911613
# Training epoch 2 took 11.743s
# Validation rmse for 2th set 2 epoch is 0.44226605167415406
# Validation rmse for 2th set is 0.4365181288736452
# current learning rate 0.0011819655769629315
# Training epoch 0 took 11.785s
# Validation rmse for 3th set 0 epoch is 0.46144619233928097
# current learning rate 0.004164773029284211
# Training epoch 1 took 11.609s
# Validation rmse for 3th set 1 epoch is 0.5127787853600059
# current learning rate 0.0003600091192911613
# Training epoch 2 took 11.600s
# Validation rmse for 3th set 2 epoch is 0.4388612094750809
# Validation rmse for 3th set is 0.4565313859784847
# Overall Validation rmse for [181, 41, 93, 88, 329, 180, 0.0011819655769629315, 0.004164773029284211, 0.0003600091192911613, 0.34813484715048093, 0.4893305527741493, 0.039957928210836186, 29, 29, 29, 24, 679] is 0.4536050032496653
#
#
# current learning rate 0.005696634895750646
# Training epoch 0 took 11.319s
# Validation rmse for 0th set 0 epoch is 0.4486975437512296
# current learning rate 0.002079163080552713
# Training epoch 1 took 11.368s
# Validation rmse for 0th set 1 epoch is 0.4404395469389359
# current learning rate 3.381514267820292e-05
# Training epoch 2 took 11.347s
# Validation rmse for 0th set 2 epoch is 0.4416879040510163
# Validation rmse for 0th set is 0.44057436242934117
# current learning rate 0.005696634895750646
# Training epoch 0 took 11.444s
# Validation rmse for 1th set 0 epoch is 0.44720249454667343
# current learning rate 0.002079163080552713
# Training epoch 1 took 11.314s
# Validation rmse for 1th set 1 epoch is 0.4426435318283009
# current learning rate 3.381514267820292e-05
# Training epoch 2 took 11.365s
# Validation rmse for 1th set 2 epoch is 0.4391023024993493
# Validation rmse for 1th set is 0.4399905676276229
# current learning rate 0.005696634895750646
# Training epoch 0 took 11.382s
# Validation rmse for 2th set 0 epoch is 0.45022930441570663
# current learning rate 0.002079163080552713
# Training epoch 1 took 11.327s
# Validation rmse for 2th set 1 epoch is 0.43764073854421187
# current learning rate 3.381514267820292e-05
# Training epoch 2 took 11.397s
# Validation rmse for 2th set 2 epoch is 0.4400950346525602
# Validation rmse for 2th set is 0.4389744024328843
# current learning rate 0.005696634895750646
# Training epoch 0 took 11.420s
# Validation rmse for 3th set 0 epoch is 0.44821969905465747
# current learning rate 0.002079163080552713
# Training epoch 1 took 11.365s
# Validation rmse for 3th set 1 epoch is 0.4388398700010437
# current learning rate 3.381514267820292e-05
# Training epoch 2 took 11.426s
# Validation rmse for 3th set 2 epoch is 0.43984614089315904
# Validation rmse for 3th set is 0.43906728030511943
# Overall Validation rmse for [304, 465, 25, 201, 191, 64, 0.005696634895750646, 0.002079163080552713, 3.381514267820292e-05, 0.30991924208425253, 0.22861901577605775, 0.028421697443432432, 10, 14, 15, 16, 3816] is 0.4396521554186731
#
#
# current learning rate 0.004235571105164075
# Training epoch 0 took 10.023s
# Validation rmse for 0th set 0 epoch is 0.45016459301196876
# current learning rate 0.0021907894494587144
# Training epoch 1 took 9.902s
# Validation rmse for 0th set 1 epoch is 0.4370532636797854
# current learning rate 0.000248463381689824
# Training epoch 2 took 9.847s
# Validation rmse for 0th set 2 epoch is 0.44145628427073696
# Validation rmse for 0th set is 0.43825302372096353
# current learning rate 0.004235571105164075
# Training epoch 0 took 10.012s
# Validation rmse for 1th set 0 epoch is 0.45218443456499957
# current learning rate 0.0021907894494587144
# Training epoch 1 took 10.023s
# Validation rmse for 1th set 1 epoch is 0.4412873919845981
# current learning rate 0.000248463381689824
# Training epoch 2 took 9.941s
# Validation rmse for 1th set 2 epoch is 0.44367673649104666
# Validation rmse for 1th set is 0.4416433835904929
# current learning rate 0.004235571105164075
# Training epoch 0 took 9.942s
# Validation rmse for 2th set 0 epoch is 0.44858717592562014
# current learning rate 0.0021907894494587144
# Training epoch 1 took 9.913s
# Validation rmse for 2th set 1 epoch is 0.4412362386852834
# current learning rate 0.000248463381689824
# Training epoch 2 took 9.907s
# Validation rmse for 2th set 2 epoch is 0.44188284002168815
# Validation rmse for 2th set is 0.4403782289288404
# current learning rate 0.004235571105164075
# Training epoch 0 took 9.981s
# Validation rmse for 3th set 0 epoch is 0.45043451270305646
# current learning rate 0.0021907894494587144
# Training epoch 1 took 9.872s
# Validation rmse for 3th set 1 epoch is 0.44194279363331174
# current learning rate 0.000248463381689824
# Training epoch 2 took 10.037s
# Validation rmse for 3th set 2 epoch is 0.44215611065161226
# Validation rmse for 3th set is 0.4409287943805354
# Overall Validation rmse for [260, 289, 95, 148, 169, 74, 0.004235571105164075, 0.0021907894494587144, 0.000248463381689824, 0.02502996318007867, 0.3337165910073882, 0.03353189348090798, 24, 28, 10, 24, 2915] is 0.440302673537818
#
#
# current learning rate 0.00989536454253304
# Training epoch 0 took 10.316s
# Validation rmse for 0th set 0 epoch is 0.4399231401500741
# current learning rate 0.0005192036056326602
# Training epoch 1 took 10.410s
# Validation rmse for 0th set 1 epoch is 0.4344109485555618
# current learning rate 2.616697456085447e-05
# Training epoch 2 took 10.300s
# Validation rmse for 0th set 2 epoch is 0.4348493740869265
# Validation rmse for 0th set is 0.4346179371480898
# current learning rate 0.00989536454253304
# Training epoch 0 took 10.351s
# Validation rmse for 1th set 0 epoch is 0.44323249101111944
# current learning rate 0.0005192036056326602
# Training epoch 1 took 10.338s
# Validation rmse for 1th set 1 epoch is 0.43421206111093097
# current learning rate 2.616697456085447e-05
# Training epoch 2 took 10.190s
# Validation rmse for 1th set 2 epoch is 0.43437767809937416
# Validation rmse for 1th set is 0.4343289848219536
# current learning rate 0.00989536454253304
# Training epoch 0 took 10.315s
# Validation rmse for 2th set 0 epoch is 0.442952238128948
# current learning rate 0.0005192036056326602
# Training epoch 1 took 10.358s
# Validation rmse for 2th set 1 epoch is 0.4345608091100434
# current learning rate 2.616697456085447e-05
# Training epoch 2 took 10.327s
# Validation rmse for 2th set 2 epoch is 0.4341537364734803
# Validation rmse for 2th set is 0.4345075194521424
# current learning rate 0.00989536454253304
# Training epoch 0 took 10.314s
# Validation rmse for 3th set 0 epoch is 0.4436154588794681
# current learning rate 0.0005192036056326602
# Training epoch 1 took 10.245s
# Validation rmse for 3th set 1 epoch is 0.43554148771277257
# current learning rate 2.616697456085447e-05
# Training epoch 2 took 10.312s
# Validation rmse for 3th set 2 epoch is 0.4361803144036617
# Validation rmse for 3th set is 0.4358543685729925
# Overall Validation rmse for [69, 412, 137, 186, 148, 235, 0.00989536454253304, 0.0005192036056326602, 2.616697456085447e-05, 0.06536249763611351, 0.3269010544072338, 0.012664580126989108, 25, 30, 13, 25, 3213] is 0.434827619123931
#
#
# current learning rate 0.009546139481056683
# Training epoch 0 took 10.035s
# Validation rmse for 0th set 0 epoch is 0.458763563469161
# current learning rate 0.0033160090660807216
# Training epoch 1 took 9.995s
# Validation rmse for 0th set 1 epoch is 0.4447552873089401
# current learning rate 1.0644941307299917e-05
# Training epoch 2 took 10.046s
# Validation rmse for 0th set 2 epoch is 0.44749365929340207
# Validation rmse for 0th set is 0.44593638730576435
# current learning rate 0.009546139481056683
# Training epoch 0 took 9.954s
# Validation rmse for 1th set 0 epoch is 0.45012696636558175
# current learning rate 0.0033160090660807216
# Training epoch 1 took 9.891s
# Validation rmse for 1th set 1 epoch is 0.4562725253700233
# current learning rate 1.0644941307299917e-05
# Training epoch 2 took 9.968s
# Validation rmse for 1th set 2 epoch is 0.44723784574311204
# Validation rmse for 1th set is 0.4486057805182125
# current learning rate 0.009546139481056683
# Training epoch 0 took 9.908s
# Validation rmse for 2th set 0 epoch is 0.4582691311270624
# current learning rate 0.0033160090660807216
# Training epoch 1 took 9.868s
# Validation rmse for 2th set 1 epoch is 0.4388662837565049
# current learning rate 1.0644941307299917e-05
# Training epoch 2 took 9.937s
# Validation rmse for 2th set 2 epoch is 0.44655695009071367
# Validation rmse for 2th set is 0.4427106529460853
# current learning rate 0.009546139481056683
# Training epoch 0 took 10.091s
# Validation rmse for 3th set 0 epoch is 0.46341021571720836
# current learning rate 0.0033160090660807216
# Training epoch 1 took 10.010s
# Validation rmse for 3th set 1 epoch is 0.44411991761518804
# current learning rate 1.0644941307299917e-05
# Training epoch 2 took 9.932s
# Validation rmse for 3th set 2 epoch is 0.4474227581184982
# Validation rmse for 3th set is 0.44572883438678085
# Overall Validation rmse for [389, 357, 64, 65, 133, 201, 0.009546139481056683, 0.0033160090660807216, 1.0644941307299917e-05, 0.24951559212312116, 0.33715615578705893, 0.048597250124983296, 13, 12, 20, 23, 4720] is 0.4457503011421918
#
#
# current learning rate 0.003545262663187687
# Training epoch 0 took 11.020s
# Validation rmse for 0th set 0 epoch is 0.4461564448822163
# current learning rate 0.000609780840453713
# Training epoch 1 took 11.077s
# Validation rmse for 0th set 1 epoch is 0.43923115306907906
# current learning rate 3.910933172251062e-05
# Training epoch 2 took 11.149s
# Validation rmse for 0th set 2 epoch is 0.43967909449878284
# Validation rmse for 0th set is 0.43950501687704346
# current learning rate 0.003545262663187687
# Training epoch 0 took 11.062s
# Validation rmse for 1th set 0 epoch is 0.44830526911575047
# current learning rate 0.000609780840453713
# Training epoch 1 took 11.015s
# Validation rmse for 1th set 1 epoch is 0.4389329660898315
# current learning rate 3.910933172251062e-05
# Training epoch 2 took 10.994s
# Validation rmse for 1th set 2 epoch is 0.4394290109820915
# Validation rmse for 1th set is 0.4394363791489641
# current learning rate 0.003545262663187687
# Training epoch 0 took 11.115s
# Validation rmse for 2th set 0 epoch is 0.4472703817017425
# current learning rate 0.000609780840453713
# Training epoch 1 took 11.031s
# Validation rmse for 2th set 1 epoch is 0.4400720441854745
# current learning rate 3.910933172251062e-05
# Training epoch 2 took 11.089s
# Validation rmse for 2th set 2 epoch is 0.4398495213327335
# Validation rmse for 2th set is 0.440079058841776
# current learning rate 0.003545262663187687
# Training epoch 0 took 11.015s
# Validation rmse for 3th set 0 epoch is 0.4504900778751035
# current learning rate 0.000609780840453713
# Training epoch 1 took 11.024s
# Validation rmse for 3th set 1 epoch is 0.4405140413795399
# current learning rate 3.910933172251062e-05
# Training epoch 2 took 11.157s
# Validation rmse for 3th set 2 epoch is 0.4412934121482301
# Validation rmse for 3th set is 0.4411159915210235
# Overall Validation rmse for [503, 421, 217, 143, 64, 170, 0.003545262663187687, 0.000609780840453713, 3.910933172251062e-05, 0.04837235986274339, 0.15967360651759405, 0.0207131497257335, 13, 28, 24, 13, 4561] is 0.4400346256791281
#
#
# current learning rate 0.0017480124336754217
# Training epoch 0 took 13.149s
# Validation rmse for 0th set 0 epoch is 0.45763496576659746
# current learning rate 0.0013958156207923523
# Training epoch 1 took 13.185s
# Validation rmse for 0th set 1 epoch is 0.44738141176442775
# current learning rate 1.0440310373117891e-05
# Training epoch 2 took 13.215s
# Validation rmse for 0th set 2 epoch is 0.45004894150894625
# Validation rmse for 0th set is 0.4484897406905273
# current learning rate 0.0017480124336754217
# Training epoch 0 took 13.150s
# Validation rmse for 1th set 0 epoch is 0.45730378161795265
# current learning rate 0.0013958156207923523
# Training epoch 1 took 13.048s
# Validation rmse for 1th set 1 epoch is 0.4558019807001926
# current learning rate 1.0440310373117891e-05
# Training epoch 2 took 13.055s
# Validation rmse for 1th set 2 epoch is 0.44910470597277996
# Validation rmse for 1th set is 0.4503351632253034
# current learning rate 0.0017480124336754217
# Training epoch 0 took 13.213s
# Validation rmse for 2th set 0 epoch is 0.45783801160564336
# current learning rate 0.0013958156207923523
# Training epoch 1 took 13.144s
# Validation rmse for 2th set 1 epoch is 0.4464701097272777
# current learning rate 1.0440310373117891e-05
# Training epoch 2 took 13.078s
# Validation rmse for 2th set 2 epoch is 0.4492605364739071
# Validation rmse for 2th set is 0.4477463684571641
# current learning rate 0.0017480124336754217
# Training epoch 0 took 13.078s
# Validation rmse for 3th set 0 epoch is 0.4586684323925936
# current learning rate 0.0013958156207923523
# Training epoch 1 took 13.156s
# Validation rmse for 3th set 1 epoch is 0.44890063932713736
# current learning rate 1.0440310373117891e-05
# Training epoch 2 took 13.113s
# Validation rmse for 3th set 2 epoch is 0.4497603941614052
# Validation rmse for 3th set is 0.4486120142538059
# Overall Validation rmse for [66, 427, 30, 57, 122, 225, 0.0017480124336754217, 0.0013958156207923523, 1.0440310373117891e-05, 0.33709448978742473, 0.32393989595359024, 0.04206930595986773, 16, 29, 24, 20, 1464] is 0.44879682389173964
#
#
# current learning rate 0.006126565653309762
# Training epoch 0 took 12.458s
# Validation rmse for 0th set 0 epoch is 0.43993387396607214
# current learning rate 0.003521649023656683
# Training epoch 1 took 12.390s
# Validation rmse for 0th set 1 epoch is 0.4281882565898643
# current learning rate 3.775312222605937e-05
# Training epoch 2 took 12.495s
# Validation rmse for 0th set 2 epoch is 0.4303776423764698
# Validation rmse for 0th set is 0.42838144628823477
# current learning rate 0.006126565653309762
# Training epoch 0 took 12.437s
# Validation rmse for 1th set 0 epoch is 0.4406895568074298
# current learning rate 0.003521649023656683
# Training epoch 1 took 12.363s
# Validation rmse for 1th set 1 epoch is 0.43386191172527044
# current learning rate 3.775312222605937e-05
# Training epoch 2 took 12.397s
# Validation rmse for 1th set 2 epoch is 0.42982161233905014
# Validation rmse for 1th set is 0.4304297895764913
# current learning rate 0.006126565653309762
# Training epoch 0 took 12.398s
# Validation rmse for 2th set 0 epoch is 0.4442050448376003
# current learning rate 0.003521649023656683
# Training epoch 1 took 12.396s
# Validation rmse for 2th set 1 epoch is 0.42957465836176684
# current learning rate 3.775312222605937e-05
# Training epoch 2 took 12.414s
# Validation rmse for 2th set 2 epoch is 0.4308283078304698
# Validation rmse for 2th set is 0.42978755666632906
# current learning rate 0.006126565653309762
# Training epoch 0 took 12.379s
# Validation rmse for 3th set 0 epoch is 0.44222774576491497
# current learning rate 0.003521649023656683
# Training epoch 1 took 12.369s
# Validation rmse for 3th set 1 epoch is 0.4321650170154768
# current learning rate 3.775312222605937e-05
# Training epoch 2 took 12.408s
# Validation rmse for 3th set 2 epoch is 0.4311162008625262
# Validation rmse for 3th set is 0.4303858344532177
# Overall Validation rmse for [460, 504, 93, 46, 344, 157, 0.006126565653309762, 0.003521649023656683, 3.775312222605937e-05, 0.1738819367308356, 0.37829724023865546, 0.01980491377116812, 12, 30, 13, 22, 4110] is 0.42974695392814244
#
#
# current learning rate 0.008324180377322297
# Training epoch 0 took 10.318s
# Validation rmse for 0th set 0 epoch is 0.44528507873793605
# current learning rate 0.001988563646826454
# Training epoch 1 took 10.512s
# Validation rmse for 0th set 1 epoch is 0.4381146429419078
# current learning rate 0.0005783708472141564
# Training epoch 2 took 10.418s
# Validation rmse for 0th set 2 epoch is 0.4320326470953235
# Validation rmse for 0th set is 0.43386971295746934
# current learning rate 0.008324180377322297
# Training epoch 0 took 10.548s
# Validation rmse for 1th set 0 epoch is 0.4550509577656991
# current learning rate 0.001988563646826454
# Training epoch 1 took 10.412s
# Validation rmse for 1th set 1 epoch is 0.44527264636361696
# current learning rate 0.0005783708472141564
# Training epoch 2 took 10.414s
# Validation rmse for 1th set 2 epoch is 0.436430600732244
# Validation rmse for 1th set is 0.43971450722520805
# current learning rate 0.008324180377322297
# Training epoch 0 took 10.671s
# Validation rmse for 2th set 0 epoch is 0.4528019971902936
# current learning rate 0.001988563646826454
# Training epoch 1 took 10.488s
# Validation rmse for 2th set 1 epoch is 0.4346551242751538
# current learning rate 0.0005783708472141564
# Training epoch 2 took 10.387s
# Validation rmse for 2th set 2 epoch is 0.433961663261901
# Validation rmse for 2th set is 0.43418708378571597
# current learning rate 0.008324180377322297
# Training epoch 0 took 10.551s
# Validation rmse for 3th set 0 epoch is 0.444620337172826
# current learning rate 0.001988563646826454
# Training epoch 1 took 10.547s
# Validation rmse for 3th set 1 epoch is 0.43440182185476195
# current learning rate 0.0005783708472141564
# Training epoch 2 took 10.383s
# Validation rmse for 3th set 2 epoch is 0.4350900758040399
# Validation rmse for 3th set is 0.4338572798442135
# Overall Validation rmse for [368, 276, 211, 253, 203, 118, 0.008324180377322297, 0.001988563646826454, 0.0005783708472141564, 0.23292787618170765, 0.4409859455655716, 0.034626579503888304, 29, 11, 18, 10, 3067] is 0.4354142678778076
#
#
# current learning rate 0.009850210366205779
# Training epoch 0 took 10.792s
# Validation rmse for 0th set 0 epoch is 0.43822339331594057
# current learning rate 0.0001103228216025373
# Training epoch 1 took 10.695s
# Validation rmse for 0th set 1 epoch is 0.4370499710289488
# current learning rate 0.00029066242594800947
# Training epoch 2 took 10.688s
# Validation rmse for 0th set 2 epoch is 0.4338056131675472
# Validation rmse for 0th set is 0.43488814511021207
# current learning rate 0.009850210366205779
# Training epoch 0 took 10.823s
# Validation rmse for 1th set 0 epoch is 0.44212368939020197
# current learning rate 0.0001103228216025373
# Training epoch 1 took 10.882s
# Validation rmse for 1th set 1 epoch is 0.43957213162582076
# current learning rate 0.00029066242594800947
# Training epoch 2 took 10.763s
# Validation rmse for 1th set 2 epoch is 0.43639435931603765
# Validation rmse for 1th set is 0.4372494588334212
# current learning rate 0.009850210366205779
# Training epoch 0 took 10.737s
# Validation rmse for 2th set 0 epoch is 0.4419621785728444
# current learning rate 0.0001103228216025373
# Training epoch 1 took 10.688s
# Validation rmse for 2th set 1 epoch is 0.4388206297119756
# current learning rate 0.00029066242594800947
# Training epoch 2 took 10.724s
# Validation rmse for 2th set 2 epoch is 0.4357896348741018
# Validation rmse for 2th set is 0.43657840353421196
# current learning rate 0.009850210366205779
# Training epoch 0 took 10.751s
# Validation rmse for 3th set 0 epoch is 0.44209605415828584
# current learning rate 0.0001103228216025373
# Training epoch 1 took 10.769s
# Validation rmse for 3th set 1 epoch is 0.43800170446255676
# current learning rate 0.00029066242594800947
# Training epoch 2 took 10.685s
# Validation rmse for 3th set 2 epoch is 0.43643697825069067
# Validation rmse for 3th set is 0.43651883096919425
# Overall Validation rmse for [195, 259, 116, 46, 352, 235, 0.009850210366205779, 0.0001103228216025373, 0.00029066242594800947, 0.19736197303963907, 0.4996227535561094, 0.0203334766353617, 12, 20, 13, 30, 1986] is 0.4363095747948679
#
#
# current learning rate 0.0066990746570494645
# Training epoch 0 took 13.194s
# Validation rmse for 0th set 0 epoch is 0.4382174499208862
# current learning rate 0.0041132966734793615
# Training epoch 1 took 13.066s
# Validation rmse for 0th set 1 epoch is 0.4262609156947234
# current learning rate 0.0002957376663370975
# Training epoch 2 took 13.107s
# Validation rmse for 0th set 2 epoch is 0.4238896752780939
# Validation rmse for 0th set is 0.4224835546305811
# current learning rate 0.0066990746570494645
# Training epoch 0 took 13.206s
# Validation rmse for 1th set 0 epoch is 0.43565656812729914
# current learning rate 0.0041132966734793615
# Training epoch 1 took 13.110s
# Validation rmse for 1th set 1 epoch is 0.4289498245680101
# current learning rate 0.0002957376663370975
# Training epoch 2 took 13.126s
# Validation rmse for 1th set 2 epoch is 0.4209703400421743
# Validation rmse for 1th set is 0.4217198419347202
# current learning rate 0.0066990746570494645
# Training epoch 0 took 13.123s
# Validation rmse for 2th set 0 epoch is 0.4351642552906596
# current learning rate 0.0041132966734793615
# Training epoch 1 took 13.123s
# Validation rmse for 2th set 1 epoch is 0.4235318757627445
# current learning rate 0.0002957376663370975
# Training epoch 2 took 13.125s
# Validation rmse for 2th set 2 epoch is 0.4211143509172739
# Validation rmse for 2th set is 0.42010675686364124
# current learning rate 0.0066990746570494645
# Training epoch 0 took 13.134s
# Validation rmse for 3th set 0 epoch is 0.43641568659474705
# current learning rate 0.0041132966734793615
# Training epoch 1 took 13.076s
# Validation rmse for 3th set 1 epoch is 0.42414154335999676
# current learning rate 0.0002957376663370975
# Training epoch 2 took 13.136s
# Validation rmse for 3th set 2 epoch is 0.42104349382598577
# Validation rmse for 3th set is 0.4208007610048285
# Overall Validation rmse for [248, 494, 103, 252, 496, 70, 0.0066990746570494645, 0.0041132966734793615, 0.0002957376663370975, 0.38372882743690007, 0.013702638047768126, 0.009912707503581527, 12, 24, 18, 11, 2809] is 0.4212786923876716
#
#
# current learning rate 0.002582812330021152
# Training epoch 0 took 16.807s
# Validation rmse for 0th set 0 epoch is 0.4284092490998222
# current learning rate 0.004586743163427907
# Training epoch 1 took 16.883s
# Validation rmse for 0th set 1 epoch is 0.42299828037398973
# current learning rate 0.0005428040012841644
# Training epoch 2 took 16.796s
# Validation rmse for 0th set 2 epoch is 0.41406649248054056
# Validation rmse for 0th set is 0.41389757719509984
# current learning rate 0.002582812330021152
# Training epoch 0 took 16.846s
# Validation rmse for 1th set 0 epoch is 0.43119187946914433
# current learning rate 0.004586743163427907
# Training epoch 1 took 16.830s
# Validation rmse for 1th set 1 epoch is 0.4259714223256821
# current learning rate 0.0005428040012841644
# Training epoch 2 took 16.798s
# Validation rmse for 1th set 2 epoch is 0.41359994122303545
# Validation rmse for 1th set is 0.4146955306405214
# current learning rate 0.002582812330021152
# Training epoch 0 took 16.795s
# Validation rmse for 2th set 0 epoch is 0.42904778369473373
# current learning rate 0.004586743163427907
# Training epoch 1 took 16.781s
# Validation rmse for 2th set 1 epoch is 0.42051667319413844
# current learning rate 0.0005428040012841644
# Training epoch 2 took 16.856s
# Validation rmse for 2th set 2 epoch is 0.4133855273316723
# Validation rmse for 2th set is 0.4127614805689933
# current learning rate 0.002582812330021152
# Training epoch 0 took 16.919s
# Validation rmse for 3th set 0 epoch is 0.43081375957635437
# current learning rate 0.004586743163427907
# Training epoch 1 took 16.827s
# Validation rmse for 3th set 1 epoch is 0.4224984087520217
# current learning rate 0.0005428040012841644
# Training epoch 2 took 16.838s
# Validation rmse for 3th set 2 epoch is 0.41535844870672883
# Validation rmse for 3th set is 0.4148430006662807
# Overall Validation rmse for [428, 488, 70, 33, 450, 201, 0.002582812330021152, 0.004586743163427907, 0.0005428040012841644, 0.23849806383805164, 0.07159458389014121, 0.0012884001368868084, 11, 21, 20, 19, 1571] is 0.414050221164205
#
#
# current learning rate 0.0012143000079396062
# Training epoch 0 took 23.736s
# Validation rmse for 0th set 0 epoch is 0.4363825768621024
# current learning rate 0.004847588544626858
# Training epoch 1 took 23.691s
# Validation rmse for 0th set 1 epoch is 0.4323176289188246
# current learning rate 3.039067708426306e-05
# Training epoch 2 took 23.716s
# Validation rmse for 0th set 2 epoch is 0.4232392404897532
# Validation rmse for 0th set is 0.4236961460358632
# current learning rate 0.0012143000079396062
# Training epoch 0 took 23.836s
# Validation rmse for 1th set 0 epoch is 0.43869100666060723
# current learning rate 0.004847588544626858
# Training epoch 1 took 23.726s
# Validation rmse for 1th set 1 epoch is 0.4397033924955416
# current learning rate 3.039067708426306e-05
# Training epoch 2 took 23.708s
# Validation rmse for 1th set 2 epoch is 0.42244750232523576
# Validation rmse for 1th set is 0.42483603431678035
# current learning rate 0.0012143000079396062
# Training epoch 0 took 23.642s
# Validation rmse for 2th set 0 epoch is 0.43714261755459644
# current learning rate 0.004847588544626858
# Training epoch 1 took 23.633s
# Validation rmse for 2th set 1 epoch is 0.4297040753757979
# current learning rate 3.039067708426306e-05
# Training epoch 2 took 23.691s
# Validation rmse for 2th set 2 epoch is 0.42226611265888475
# Validation rmse for 2th set is 0.42240879491963235
# current learning rate 0.0012143000079396062
# Training epoch 0 took 23.638s
# Validation rmse for 3th set 0 epoch is 0.4405304587257296
# current learning rate 0.004847588544626858
# Training epoch 1 took 23.702s
# Validation rmse for 3th set 1 epoch is 0.4294176838659212
# current learning rate 3.039067708426306e-05
# Training epoch 2 took 23.674s
# Validation rmse for 3th set 2 epoch is 0.42312506267809463
# Validation rmse for 3th set is 0.4232551058421812
# Overall Validation rmse for [212, 299, 144, 224, 473, 146, 0.0012143000079396062, 0.004847588544626858, 3.039067708426306e-05, 0.26943107096340274, 0.17366661623195545, 0.004465900951026415, 22, 15, 29, 23, 464] is 0.42354992470386066
#
#
# current learning rate 0.004352147885128709
# Training epoch 0 took 14.029s
# Validation rmse for 0th set 0 epoch is 0.4292478195474388
# current learning rate 0.004799784588296129
# Training epoch 1 took 14.072s
# Validation rmse for 0th set 1 epoch is 0.42069769198781853
# current learning rate 0.0008674740857502088
# Training epoch 2 took 14.066s
# Validation rmse for 0th set 2 epoch is 0.41379641853972526
# Validation rmse for 0th set is 0.4126918496019394
# current learning rate 0.004352147885128709
# Training epoch 0 took 14.166s
# Validation rmse for 1th set 0 epoch is 0.4306398375251053
# current learning rate 0.004799784588296129
# Training epoch 1 took 14.219s
# Validation rmse for 1th set 1 epoch is 0.4245570233630502
# current learning rate 0.0008674740857502088
# Training epoch 2 took 14.234s
# Validation rmse for 1th set 2 epoch is 0.4133237825632284
# Validation rmse for 1th set is 0.4138100234688463
# current learning rate 0.004352147885128709
# Training epoch 0 took 14.216s
# Validation rmse for 2th set 0 epoch is 0.42953677648335953
# current learning rate 0.004799784588296129
# Training epoch 1 took 14.059s
# Validation rmse for 2th set 1 epoch is 0.41943692404567867
# current learning rate 0.0008674740857502088
# Training epoch 2 took 14.067s
# Validation rmse for 2th set 2 epoch is 0.41279383233918665
# Validation rmse for 2th set is 0.41199598912425006
# current learning rate 0.004352147885128709
# Training epoch 0 took 14.158s
# Validation rmse for 3th set 0 epoch is 0.43037119215891384
# current learning rate 0.004799784588296129
# Training epoch 1 took 14.134s
# Validation rmse for 3th set 1 epoch is 0.42155783849239403
# current learning rate 0.0008674740857502088
# Training epoch 2 took 14.241s
# Validation rmse for 3th set 2 epoch is 0.41495177012072226
# Validation rmse for 3th set is 0.41385751722993525
# Overall Validation rmse for [433, 380, 179, 73, 508, 193, 0.004352147885128709, 0.004799784588296129, 0.0008674740857502088, 0.1639507990732214, 0.05043616270685462, 0.0012438307389190054, 27, 21, 12, 30, 2071] is 0.4130895901234235
#
#
# current learning rate 0.0011115410272128981
# Training epoch 0 took 7.300s
# Validation rmse for 0th set 0 epoch is 0.4444365354344209
# current learning rate 0.0012435337130108602
# Training epoch 1 took 7.245s
# Validation rmse for 0th set 1 epoch is 0.43147088080592044
# current learning rate 0.0004872201195116161
# Training epoch 2 took 7.122s
# Validation rmse for 0th set 2 epoch is 0.42558978898492594
# Validation rmse for 0th set is 0.4263334434264275
# current learning rate 0.0011115410272128981
# Training epoch 0 took 7.315s
# Validation rmse for 1th set 0 epoch is 0.4448206301171038
# current learning rate 0.0012435337130108602
# Training epoch 1 took 7.165s
# Validation rmse for 1th set 1 epoch is 0.43191420704573524
# current learning rate 0.0004872201195116161
# Training epoch 2 took 7.185s
# Validation rmse for 1th set 2 epoch is 0.4252131953501771
# Validation rmse for 1th set is 0.426283388984671
# current learning rate 0.0011115410272128981
# Training epoch 0 took 7.220s
# Validation rmse for 2th set 0 epoch is 0.4439828973367007
# current learning rate 0.0012435337130108602
# Training epoch 1 took 6.973s
# Validation rmse for 2th set 1 epoch is 0.4315592402770306
# current learning rate 0.0004872201195116161
# Training epoch 2 took 7.278s
# Validation rmse for 2th set 2 epoch is 0.4257066874822813
# Validation rmse for 2th set is 0.42631536060913744
# current learning rate 0.0011115410272128981
# Training epoch 0 took 7.249s
# Validation rmse for 3th set 0 epoch is 0.4454064187914537
# current learning rate 0.0012435337130108602
# Training epoch 1 took 7.126s
# Validation rmse for 3th set 1 epoch is 0.43261116252251786
# current learning rate 0.0004872201195116161
# Training epoch 2 took 7.241s
# Validation rmse for 3th set 2 epoch is 0.4260792179733963
# Validation rmse for 3th set is 0.42658948511270667
# Overall Validation rmse for [439, 27, 199, 179, 499, 91, 0.0011115410272128981, 0.0012435337130108602, 0.0004872201195116161, 0.11040570871568951, 0.11176015695285965, 0.0009259842579970647, 29, 22, 12, 14, 2678] is 0.4263804369949782
#
#
# current learning rate 0.004423086914360238
# Training epoch 0 took 15.279s
# Validation rmse for 0th set 0 epoch is 0.4274448947140806
# current learning rate 0.00488317667513295
# Training epoch 1 took 15.175s
# Validation rmse for 0th set 1 epoch is 0.42040458150359195
# current learning rate 0.00015210772295550437
# Training epoch 2 took 15.181s
# Validation rmse for 0th set 2 epoch is 0.41419330114125447
# Validation rmse for 0th set is 0.4137454476363795
# current learning rate 0.004423086914360238
# Training epoch 0 took 15.293s
# Validation rmse for 1th set 0 epoch is 0.4319395950592272
# current learning rate 0.00488317667513295
# Training epoch 1 took 15.245s
# Validation rmse for 1th set 1 epoch is 0.41960910381337874
# current learning rate 0.00015210772295550437
# Training epoch 2 took 15.354s
# Validation rmse for 1th set 2 epoch is 0.41334481347126995
# Validation rmse for 1th set is 0.41327647894107206
# current learning rate 0.004423086914360238
# Training epoch 0 took 15.178s
# Validation rmse for 2th set 0 epoch is 0.42875607469838856
# current learning rate 0.00488317667513295
# Training epoch 1 took 15.125s
# Validation rmse for 2th set 1 epoch is 0.4214048002008269
# current learning rate 0.00015210772295550437
# Training epoch 2 took 15.204s
# Validation rmse for 2th set 2 epoch is 0.41343458711033154
# Validation rmse for 2th set is 0.41319002022374507
# current learning rate 0.004423086914360238
# Training epoch 0 took 15.120s
# Validation rmse for 3th set 0 epoch is 0.4313847132455034
# current learning rate 0.00488317667513295
# Training epoch 1 took 15.198s
# Validation rmse for 3th set 1 epoch is 0.4199945276964344
# current learning rate 0.00015210772295550437
# Training epoch 2 took 15.126s
# Validation rmse for 3th set 2 epoch is 0.41482771361874815
# Validation rmse for 3th set is 0.4141277129345136
# Overall Validation rmse for [470, 140, 40, 143, 430, 90, 0.004423086914360238, 0.00488317667513295, 0.00015210772295550437, 0.16486303950244244, 0.0017653719045599885, 0.0008103836211524386, 26, 20, 17, 22, 861] is 0.41358508765386726
#
#
# current learning rate 0.009039873900351904
# Training epoch 0 took 11.584s
# Validation rmse for 0th set 0 epoch is 0.43530507727798573
# current learning rate 0.004439057969021818
# Training epoch 1 took 11.618s
# Validation rmse for 0th set 1 epoch is 0.4225991783881579
# current learning rate 0.0006595245069078268
# Training epoch 2 took 11.556s
# Validation rmse for 0th set 2 epoch is 0.4200247054643108
# Validation rmse for 0th set is 0.41927196226966457
# current learning rate 0.009039873900351904
# Training epoch 0 took 11.592s
# Validation rmse for 1th set 0 epoch is 0.4383797872402479
# current learning rate 0.004439057969021818
# Training epoch 1 took 11.565s
# Validation rmse for 1th set 1 epoch is 0.4229623102175516
# current learning rate 0.0006595245069078268
# Training epoch 2 took 11.623s
# Validation rmse for 1th set 2 epoch is 0.41991316575485954
# Validation rmse for 1th set is 0.4195690400709042
# current learning rate 0.009039873900351904
# Training epoch 0 took 11.633s
# Validation rmse for 2th set 0 epoch is 0.4423330108908297
# current learning rate 0.004439057969021818
# Training epoch 1 took 11.612s
# Validation rmse for 2th set 1 epoch is 0.4249132086186559
# current learning rate 0.0006595245069078268
# Training epoch 2 took 11.544s
# Validation rmse for 2th set 2 epoch is 0.42236982815261664
# Validation rmse for 2th set is 0.42186614255130117
# current learning rate 0.009039873900351904
# Training epoch 0 took 11.540s
# Validation rmse for 3th set 0 epoch is 0.4357411387507375
# current learning rate 0.004439057969021818
# Training epoch 1 took 11.596s
# Validation rmse for 3th set 1 epoch is 0.4225286201871156
# current learning rate 0.0006595245069078268
# Training epoch 2 took 11.559s
# Validation rmse for 3th set 2 epoch is 0.41975460176452856
# Validation rmse for 3th set is 0.4189323750914103
# Overall Validation rmse for [478, 437, 71, 89, 429, 204, 0.009039873900351904, 0.004439057969021818, 0.0006595245069078268, 0.18038839831779546, 0.046379924256424815, 0.00012079149630370159, 15, 25, 22, 27, 4759] is 0.41991145937635466
#
#
# current learning rate 0.006146117066383431
# Training epoch 0 took 12.952s
# Validation rmse for 0th set 0 epoch is 0.4342237413484158
# current learning rate 0.004963487470761761
# Training epoch 1 took 12.943s
# Validation rmse for 0th set 1 epoch is 0.4234626664257315
# current learning rate 4.3177523201273006e-05
# Training epoch 2 took 12.977s
# Validation rmse for 0th set 2 epoch is 0.42183525470304417
# Validation rmse for 0th set is 0.42064685230168886
# current learning rate 0.006146117066383431
# Training epoch 0 took 13.108s
# Validation rmse for 1th set 0 epoch is 0.4368865653960861
# current learning rate 0.004963487470761761
# Training epoch 1 took 13.044s
# Validation rmse for 1th set 1 epoch is 0.4299193080867128
# current learning rate 4.3177523201273006e-05
# Training epoch 2 took 13.046s
# Validation rmse for 1th set 2 epoch is 0.4241665364380436
# Validation rmse for 1th set is 0.42474021926640104
# current learning rate 0.006146117066383431
# Training epoch 0 took 13.034s
# Validation rmse for 2th set 0 epoch is 0.43593920619308646
# current learning rate 0.004963487470761761
# Training epoch 1 took 13.027s
# Validation rmse for 2th set 1 epoch is 0.4248218833530152
# current learning rate 4.3177523201273006e-05
# Training epoch 2 took 12.957s
# Validation rmse for 2th set 2 epoch is 0.42206251205390294
# Validation rmse for 2th set is 0.421866566872371
# current learning rate 0.006146117066383431
# Training epoch 0 took 12.960s
# Validation rmse for 3th set 0 epoch is 0.4384871857884994
# current learning rate 0.004963487470761761
# Training epoch 1 took 13.079s
# Validation rmse for 3th set 1 epoch is 0.4254570859173574
# current learning rate 4.3177523201273006e-05
# Training epoch 2 took 13.051s
# Validation rmse for 3th set 2 epoch is 0.4229313762297979
# Validation rmse for 3th set is 0.4222333242797606
# Overall Validation rmse for [389, 406, 112, 130, 443, 147, 0.006146117066383431, 0.004963487470761761, 4.3177523201273006e-05, 0.1938088003055198, 0.0907706330279945, 0.00818060948015062, 11, 10, 22, 18, 2610] is 0.4223743625596869
#
#
# current learning rate 0.0043802630717118115
# Training epoch 0 took 8.921s
# Validation rmse for 0th set 0 epoch is 0.43341902520548875
# current learning rate 0.004714911529837686
# Training epoch 1 took 8.874s
# Validation rmse for 0th set 1 epoch is 0.42637105320834084
# current learning rate 0.0004864920136950689
# Training epoch 2 took 8.899s
# Validation rmse for 0th set 2 epoch is 0.4168190587166215
# Validation rmse for 0th set is 0.4172093046511157
# current learning rate 0.0043802630717118115
# Training epoch 0 took 8.793s
# Validation rmse for 1th set 0 epoch is 0.43394784265743136
# current learning rate 0.004714911529837686
# Training epoch 1 took 8.800s
# Validation rmse for 1th set 1 epoch is 0.42411072083492646
# current learning rate 0.0004864920136950689
# Training epoch 2 took 8.850s
# Validation rmse for 1th set 2 epoch is 0.4157995501826821
# Validation rmse for 1th set is 0.4164529356599284
# current learning rate 0.0043802630717118115
# Training epoch 0 took 8.857s
# Validation rmse for 2th set 0 epoch is 0.4362606237034774
# current learning rate 0.004714911529837686
# Training epoch 1 took 8.722s
# Validation rmse for 2th set 1 epoch is 0.4279662139403884
# current learning rate 0.0004864920136950689
# Training epoch 2 took 9.032s
# Validation rmse for 2th set 2 epoch is 0.41610969747382054
# Validation rmse for 2th set is 0.417379753988085
# current learning rate 0.0043802630717118115
# Training epoch 0 took 8.877s
# Validation rmse for 3th set 0 epoch is 0.4379025065390057
# current learning rate 0.004714911529837686
# Training epoch 1 took 8.831s
# Validation rmse for 3th set 1 epoch is 0.42728001852753617
# current learning rate 0.0004864920136950689
# Training epoch 2 took 8.719s
# Validation rmse for 3th set 2 epoch is 0.41808830049413814
# Validation rmse for 3th set is 0.418814118159737
# Overall Validation rmse for [111, 278, 180, 218, 439, 61, 0.0043802630717118115, 0.004714911529837686, 0.0004864920136950689, 0.2031199100210047, 0.006480971369294425, 0.0002909041325662554, 23, 14, 20, 29, 3814] is 0.41746490155350563
#
#
# current learning rate 0.009669660388285376
# Training epoch 0 took 26.882s
# Validation rmse for 0th set 0 epoch is 0.4458008621406351
# current learning rate 0.0049301362623372265
# Training epoch 1 took 26.814s
# Validation rmse for 0th set 1 epoch is 0.4374992137145947
# current learning rate 0.0009755665868588849
# Training epoch 2 took 26.826s
# Validation rmse for 0th set 2 epoch is 0.4325665856139775
# Validation rmse for 0th set is 0.4276906529974775
# current learning rate 0.009669660388285376
# Training epoch 0 took 26.860s
# Validation rmse for 1th set 0 epoch is 0.46030380920253977
# current learning rate 0.0049301362623372265
# Training epoch 1 took 26.850s
# Validation rmse for 1th set 1 epoch is 0.43573348359841024
# current learning rate 0.0009755665868588849
# Training epoch 2 took 26.882s
# Validation rmse for 1th set 2 epoch is 0.42833559476006067
# Validation rmse for 1th set is 0.4277605524950522
# current learning rate 0.009669660388285376
# Training epoch 0 took 26.920s
# Validation rmse for 2th set 0 epoch is 0.4755722034791313
# current learning rate 0.0049301362623372265
# Training epoch 1 took 26.861s
# Validation rmse for 2th set 1 epoch is 0.4363233810090073
# current learning rate 0.0009755665868588849
# Training epoch 2 took 26.875s
# Validation rmse for 2th set 2 epoch is 0.43874999382418856
# Validation rmse for 2th set is 0.43340891120907976
# current learning rate 0.009669660388285376
# Training epoch 0 took 26.831s
# Validation rmse for 3th set 0 epoch is 0.45850998752648003
# current learning rate 0.0049301362623372265
# Training epoch 1 took 26.818s
# Validation rmse for 3th set 1 epoch is 0.43654168427419
# current learning rate 0.0009755665868588849
# Training epoch 2 took 26.872s
# Validation rmse for 3th set 2 epoch is 0.45456979897398975
# Validation rmse for 3th set is 0.43951301136211435
# Overall Validation rmse for [101, 503, 220, 159, 511, 178, 0.009669660388285376, 0.0049301362623372265, 0.0009755665868588849, 0.09054584589186263, 0.009939316525978958, 0.04820830143337782, 20, 23, 23, 30, 487] is 0.43212074597394506
#
#
# current learning rate 0.009946933509569184
# Training epoch 0 took 13.117s
# Validation rmse for 0th set 0 epoch is 0.4329558094943392
# current learning rate 0.004658731218238155
# Training epoch 1 took 12.924s
# Validation rmse for 0th set 1 epoch is 0.4212581015488886
# current learning rate 0.00035786769711797245
# Training epoch 2 took 12.938s
# Validation rmse for 0th set 2 epoch is 0.41876605688775115
# Validation rmse for 0th set is 0.417999391186426
# current learning rate 0.009946933509569184
# Training epoch 0 took 13.038s
# Validation rmse for 1th set 0 epoch is 0.4336772237613928
# current learning rate 0.004658731218238155
# Training epoch 1 took 12.923s
# Validation rmse for 1th set 1 epoch is 0.4244128888660164
# current learning rate 0.00035786769711797245
# Training epoch 2 took 12.974s
# Validation rmse for 1th set 2 epoch is 0.41752809360528614
# Validation rmse for 1th set is 0.41827594497403014
# current learning rate 0.009946933509569184
# Training epoch 0 took 13.081s
# Validation rmse for 2th set 0 epoch is 0.4332936367143629
# current learning rate 0.004658731218238155
# Training epoch 1 took 13.064s
# Validation rmse for 2th set 1 epoch is 0.420438058206423
# current learning rate 0.00035786769711797245
# Training epoch 2 took 13.001s
# Validation rmse for 2th set 2 epoch is 0.4177512098018141
# Validation rmse for 2th set is 0.4172890670789529
# current learning rate 0.009946933509569184
# Training epoch 0 took 13.025s
# Validation rmse for 3th set 0 epoch is 0.4367942271857267
# current learning rate 0.004658731218238155
# Training epoch 1 took 13.101s
# Validation rmse for 3th set 1 epoch is 0.42494821015139944
# current learning rate 0.00035786769711797245
# Training epoch 2 took 13.069s
# Validation rmse for 3th set 2 epoch is 0.4207366296416171
# Validation rmse for 3th set is 0.42037924350014977
# Overall Validation rmse for [142, 406, 78, 28, 431, 99, 0.009946933509569184, 0.004658731218238155, 0.00035786769711797245, 0.25480545687826156, 0.005951221471018498, 0.0023563652719635403, 10, 27, 19, 21, 1649] is 0.41848749415171355
#
#
# current learning rate 0.004280476907380547
# Training epoch 0 took 9.919s
# Validation rmse for 0th set 0 epoch is 0.42967241426424374
# current learning rate 0.003497981633296016
# Training epoch 1 took 9.974s
# Validation rmse for 0th set 1 epoch is 0.41975863984417666
# current learning rate 0.0004421286757640551
# Training epoch 2 took 9.722s
# Validation rmse for 0th set 2 epoch is 0.4145518422778659
# Validation rmse for 0th set is 0.41393358096318517
# current learning rate 0.004280476907380547
# Training epoch 0 took 9.827s
# Validation rmse for 1th set 0 epoch is 0.4306350109076566
# current learning rate 0.003497981633296016
# Training epoch 1 took 9.965s
# Validation rmse for 1th set 1 epoch is 0.4223785835662316
# current learning rate 0.0004421286757640551
# Training epoch 2 took 9.864s
# Validation rmse for 1th set 2 epoch is 0.41441427125782515
# Validation rmse for 1th set is 0.4148442714880527
# current learning rate 0.004280476907380547
# Training epoch 0 took 9.871s
# Validation rmse for 2th set 0 epoch is 0.43015704247269637
# current learning rate 0.003497981633296016
# Training epoch 1 took 9.742s
# Validation rmse for 2th set 1 epoch is 0.419893043608352
# current learning rate 0.0004421286757640551
# Training epoch 2 took 9.706s
# Validation rmse for 2th set 2 epoch is 0.414027591341748
# Validation rmse for 2th set is 0.41371028157369527
# current learning rate 0.004280476907380547
# Training epoch 0 took 9.907s
# Validation rmse for 3th set 0 epoch is 0.430662129276418
# current learning rate 0.003497981633296016
# Training epoch 1 took 9.809s
# Validation rmse for 3th set 1 epoch is 0.41946377745514046
# current learning rate 0.0004421286757640551
# Training epoch 2 took 9.692s
# Validation rmse for 3th set 2 epoch is 0.41546082673190365
# Validation rmse for 3th set is 0.41473958105654574
# Overall Validation rmse for [425, 138, 84, 252, 508, 100, 0.004280476907380547, 0.003497981633296016, 0.0004421286757640551, 0.08556418692743518, 0.0638964739458497, 0.0014005937313995357, 15, 17, 12, 12, 2290] is 0.4143072218204156
#
#
# current learning rate 0.004037253820183688
# Training epoch 0 took 22.001s
# Validation rmse for 0th set 0 epoch is 0.4335136381939798
# current learning rate 0.0013121365325581096
# Training epoch 1 took 21.995s
# Validation rmse for 0th set 1 epoch is 0.41393426776160913
# current learning rate 0.0004805886736155402
# Training epoch 2 took 21.972s
# Validation rmse for 0th set 2 epoch is 0.41215467629661245
# Validation rmse for 0th set is 0.41015820568010164
# current learning rate 0.004037253820183688
# Training epoch 0 took 22.002s
# Validation rmse for 1th set 0 epoch is 0.4287256158701815
# current learning rate 0.0013121365325581096
# Training epoch 1 took 22.000s
# Validation rmse for 1th set 1 epoch is 0.4158517138150115
# current learning rate 0.0004805886736155402
# Training epoch 2 took 22.028s
# Validation rmse for 1th set 2 epoch is 0.4125940139217412
# Validation rmse for 1th set is 0.41106612387505614
# current learning rate 0.004037253820183688
# Training epoch 0 took 22.031s
# Validation rmse for 2th set 0 epoch is 0.428693287260936
# current learning rate 0.0013121365325581096
# Training epoch 1 took 21.974s
# Validation rmse for 2th set 1 epoch is 0.4138607487387301
# current learning rate 0.0004805886736155402
# Training epoch 2 took 21.942s
# Validation rmse for 2th set 2 epoch is 0.41166359857174273
# Validation rmse for 2th set is 0.40976035522837145
# current learning rate 0.004037253820183688
# Training epoch 0 took 22.028s
# Validation rmse for 3th set 0 epoch is 0.43135373255440945
# current learning rate 0.0013121365325581096
# Training epoch 1 took 21.945s
# ...
# Training epoch 1 took 15.451s
# Validation rmse for 0th set 1 epoch is 0.419155203820805
# current learning rate 1.1847226830859648e-05
# Training epoch 2 took 15.607s
# Validation rmse for 0th set 2 epoch is 0.4165519988544689
# Validation rmse for 0th set is 0.4158080279053952
# current learning rate 0.005511398922337878
# Training epoch 0 took 15.569s
# Validation rmse for 1th set 0 epoch is 0.4305049284788297
# current learning rate 0.00430809950319609
# Training epoch 1 took 15.529s
# Validation rmse for 1th set 1 epoch is 0.41909404215499046
# current learning rate 1.1847226830859648e-05
# Training epoch 2 took 15.507s
# Validation rmse for 1th set 2 epoch is 0.4162488243127296
# Validation rmse for 1th set is 0.41579344457326395
# current learning rate 0.005511398922337878
# Training epoch 0 took 15.527s
# Validation rmse for 2th set 0 epoch is 0.42875718501349713
# current learning rate 0.00430809950319609
# Training epoch 1 took 15.396s
# Validation rmse for 2th set 1 epoch is 0.4188921364061002
# current learning rate 1.1847226830859648e-05
# Training epoch 2 took 15.371s
# Validation rmse for 2th set 2 epoch is 0.41602505999034095
# Validation rmse for 2th set is 0.4149869251648347
# current learning rate 0.005511398922337878
# Training epoch 0 took 15.472s
# Validation rmse for 3th set 0 epoch is 0.4317293171676891
# current learning rate 0.00430809950319609
# Training epoch 1 took 15.384s
# Validation rmse for 3th set 1 epoch is 0.41944517582075325
# current learning rate 1.1847226830859648e-05
# Training epoch 2 took 15.450s
# Validation rmse for 3th set 2 epoch is 0.41765469952488365
# Validation rmse for 3th set is 0.41668706740348455
# Overall Validation rmse for [299, 199, 17, 110, 226, 153, 0.005511398922337878, 0.00430809950319609, 1.1847226830859648e-05, 0.22250546326341922, 0.22576911076805917, 0.0004783783840919099, 12, 11, 11, 17, 766] is 0.41581930114526733
#
#
# current learning rate 0.0050895838234160376
# Training epoch 0 took 13.528s
# Validation rmse for 0th set 0 epoch is 0.42811558068105343
# current learning rate 0.0031092032400196687
# Training epoch 1 took 13.382s
# Validation rmse for 0th set 1 epoch is 0.4179742005086788
# current learning rate 0.0003110240352690577
# Training epoch 2 took 13.367s
# Validation rmse for 0th set 2 epoch is 0.4147966474442435
# Validation rmse for 0th set is 0.4133843781779226
# current learning rate 0.0050895838234160376
# Training epoch 0 took 13.455s
# Validation rmse for 1th set 0 epoch is 0.4299107597625009
# current learning rate 0.0031092032400196687
# Training epoch 1 took 13.480s
# Validation rmse for 1th set 1 epoch is 0.4201322193606955
# current learning rate 0.0003110240352690577
# Training epoch 2 took 13.462s
# Validation rmse for 1th set 2 epoch is 0.41440002564836287
# Validation rmse for 1th set is 0.4140643384759568
# current learning rate 0.0050895838234160376
# Training epoch 0 took 13.526s
# Validation rmse for 2th set 0 epoch is 0.42967365323359435
# current learning rate 0.0031092032400196687
# Training epoch 1 took 13.548s
# Validation rmse for 2th set 1 epoch is 0.41618205908283507
# current learning rate 0.0003110240352690577
# Training epoch 2 took 13.560s
# Validation rmse for 2th set 2 epoch is 0.4130819252927484
# Validation rmse for 2th set is 0.41213228657138407
# current learning rate 0.0050895838234160376
# Training epoch 0 took 13.598s
# Validation rmse for 3th set 0 epoch is 0.4299816890305834
# current learning rate 0.0031092032400196687
# Training epoch 1 took 13.553s
# Validation rmse for 3th set 1 epoch is 0.41789669834574894
# current learning rate 0.0003110240352690577
# Training epoch 2 took 13.400s
# Validation rmse for 3th set 2 epoch is 0.4150924872386526
# Validation rmse for 3th set is 0.4135748770364383
# Overall Validation rmse for [162, 343, 21, 37, 436, 118, 0.0050895838234160376, 0.0031092032400196687, 0.0003110240352690577, 0.025660420073919995, 0.13842030152329515, 0.0006953976408071051, 18, 24, 13, 28, 1312] is 0.4132895840295706
#
#
# current learning rate 0.003583987178289598
# Training epoch 0 took 7.941s
# Validation rmse for 0th set 0 epoch is 0.43304311781660665
# current learning rate 0.0040657622787365
# Training epoch 1 took 7.752s
# Validation rmse for 0th set 1 epoch is 0.4216092993584168
# current learning rate 0.0001396418172553854
# Training epoch 2 took 7.731s
# Validation rmse for 0th set 2 epoch is 0.4188564382633621
# Validation rmse for 0th set is 0.4185817716532886
# current learning rate 0.003583987178289598
# Training epoch 0 took 8.001s
# Validation rmse for 1th set 0 epoch is 0.43521757081588774
# current learning rate 0.0040657622787365
# Training epoch 1 took 7.689s
# Validation rmse for 1th set 1 epoch is 0.4228810552077395
# current learning rate 0.0001396418172553854
# Training epoch 2 took 7.897s
# Validation rmse for 1th set 2 epoch is 0.4188305619342026
# Validation rmse for 1th set is 0.4191810691857697
# current learning rate 0.003583987178289598
# Training epoch 0 took 7.782s
# Validation rmse for 2th set 0 epoch is 0.4345931290911702
# current learning rate 0.0040657622787365
# Training epoch 1 took 8.026s
# Validation rmse for 2th set 1 epoch is 0.42196649327176267
# current learning rate 0.0001396418172553854
# Training epoch 2 took 7.818s
# Validation rmse for 2th set 2 epoch is 0.41843296458290863
# Validation rmse for 2th set is 0.4183924936308542
# current learning rate 0.003583987178289598
# Training epoch 0 took 7.853s
# Validation rmse for 3th set 0 epoch is 0.43792542164337134
# current learning rate 0.0040657622787365
# Training epoch 1 took 7.766s
# Validation rmse for 3th set 1 epoch is 0.423978176205692
# current learning rate 0.0001396418172553854
# Training epoch 2 took 7.831s
# Validation rmse for 3th set 2 epoch is 0.4203189460693787
# Validation rmse for 3th set is 0.4203563222041971
# Overall Validation rmse for [409, 172, 66, 54, 511, 130, 0.003583987178289598, 0.0040657622787365, 0.0001396418172553854, 0.02981037098044862, 0.013116075462108388, 0.0010895860646283563, 18, 30, 19, 27, 4941] is 0.41912861530436396
#
#
# current learning rate 0.0033465151218486236
# Training epoch 0 took 19.687s
# Validation rmse for 0th set 0 epoch is 0.42857456949862865
# current learning rate 0.002621420022681708
# Training epoch 1 took 19.863s
# Validation rmse for 0th set 1 epoch is 0.4197272399669023
# current learning rate 5.888410024169528e-05
# Training epoch 2 took 19.633s
# Validation rmse for 0th set 2 epoch is 0.4137309148745911
# Validation rmse for 0th set is 0.41331569542522784
# current learning rate 0.0033465151218486236
# Training epoch 0 took 19.671s
# Validation rmse for 1th set 0 epoch is 0.4298512493113866
# current learning rate 0.002621420022681708
# Training epoch 1 took 19.692s
# Validation rmse for 1th set 1 epoch is 0.4214160453707551
# current learning rate 5.888410024169528e-05
# Training epoch 2 took 19.784s
# Validation rmse for 1th set 2 epoch is 0.41295080213941726
# Validation rmse for 1th set is 0.4136731845599401
# current learning rate 0.0033465151218486236
# Training epoch 0 took 19.588s
# Validation rmse for 2th set 0 epoch is 0.4279117199819626
# current learning rate 0.002621420022681708
# Training epoch 1 took 19.754s
# Validation rmse for 2th set 1 epoch is 0.4164727206547315
# current learning rate 5.888410024169528e-05
# Training epoch 2 took 19.721s
# Validation rmse for 2th set 2 epoch is 0.41208639133668923
# Validation rmse for 2th set is 0.4117250972718302
# current learning rate 0.0033465151218486236
# Training epoch 0 took 19.630s
# Validation rmse for 3th set 0 epoch is 0.4306737291864138
# current learning rate 0.002621420022681708
# Training epoch 1 took 19.623s
# Validation rmse for 3th set 1 epoch is 0.41852784128587533
# current learning rate 5.888410024169528e-05
# Training epoch 2 took 19.604s
# Validation rmse for 3th set 2 epoch is 0.41396884229488873
# Validation rmse for 3th set is 0.41367346381886183
# Overall Validation rmse for [199, 140, 31, 72, 331, 244, 0.0033465151218486236, 0.002621420022681708, 5.888410024169528e-05, 0.26611443656160894, 0.12262015001468983, 0.00010067767003525964, 21, 20, 14, 28, 419] is 0.41309764526688947
#
#
# current learning rate 0.0013710506587492261
# Training epoch 0 took 8.549s
# Validation rmse for 0th set 0 epoch is 0.4389921005620264
# current learning rate 0.0008572884205817499
# Training epoch 1 took 8.652s
# Validation rmse for 0th set 1 epoch is 0.4251319404284658
# current learning rate 0.0008673762214643696
# Training epoch 2 took 8.558s
# Validation rmse for 0th set 2 epoch is 0.42006030278412093
# Validation rmse for 0th set is 0.42000076511903456
# current learning rate 0.0013710506587492261
# Training epoch 0 took 8.580s
# Validation rmse for 1th set 0 epoch is 0.4393405777463429
# current learning rate 0.0008572884205817499
# Training epoch 1 took 8.553s
# Validation rmse for 1th set 1 epoch is 0.42674690726575576
# current learning rate 0.0008673762214643696
# Training epoch 2 took 8.506s
# Validation rmse for 1th set 2 epoch is 0.41925927051171974
# Validation rmse for 1th set is 0.4200467423341034
# current learning rate 0.0013710506587492261
# Training epoch 0 took 8.725s
# Validation rmse for 2th set 0 epoch is 0.43976928495978296
# current learning rate 0.0008572884205817499
# Training epoch 1 took 8.441s
# Validation rmse for 2th set 1 epoch is 0.4256213145162907
# current learning rate 0.0008673762214643696
# Training epoch 2 took 8.483s
# Validation rmse for 2th set 2 epoch is 0.4199616197669364
# Validation rmse for 2th set is 0.42047928989668837
# current learning rate 0.0013710506587492261
# Training epoch 0 took 8.540s
# Validation rmse for 3th set 0 epoch is 0.43908467734479323
# current learning rate 0.0008572884205817499
# Training epoch 1 took 8.511s
# Validation rmse for 3th set 1 epoch is 0.42562142436747064
# current learning rate 0.0008673762214643696
# Training epoch 2 took 8.298s
# Validation rmse for 3th set 2 epoch is 0.4213033186019904
# Validation rmse for 3th set is 0.4205494802734147
# Overall Validation rmse for [240, 175, 117, 219, 233, 245, 0.0013710506587492261, 0.0008572884205817499, 0.0008673762214643696, 0.28804079992149356, 0.2910956174091607, 0.00015126008139793593, 23, 30, 30, 26, 2706] is 0.42026914204957083
#
#
# current learning rate 0.001059753590486383
# Training epoch 0 took 6.517s
# Validation rmse for 0th set 0 epoch is 0.4459593465840352
# current learning rate 0.00025251901896782393
# Training epoch 1 took 6.511s
# Validation rmse for 0th set 1 epoch is 0.4380386941455493
# current learning rate 7.385825868704096e-05
# Training epoch 2 took 6.449s
# Validation rmse for 0th set 2 epoch is 0.43678227936746106
# Validation rmse for 0th set is 0.43739938796414285
# current learning rate 0.001059753590486383
# Training epoch 0 took 6.479s
# Validation rmse for 1th set 0 epoch is 0.44741566664432364
# current learning rate 0.00025251901896782393
# Training epoch 1 took 6.481s
# Validation rmse for 1th set 1 epoch is 0.4390990681220315
# current learning rate 7.385825868704096e-05
# Training epoch 2 took 6.574s
# Validation rmse for 1th set 2 epoch is 0.43597890847669524
# Validation rmse for 1th set is 0.43720227126926603
# current learning rate 0.001059753590486383
# Training epoch 0 took 6.431s
# Validation rmse for 2th set 0 epoch is 0.44586568463416804
# current learning rate 0.00025251901896782393
# Training epoch 1 took 6.637s
# Validation rmse for 2th set 1 epoch is 0.43729152135253224
# current learning rate 7.385825868704096e-05
# Training epoch 2 took 6.692s
# Validation rmse for 2th set 2 epoch is 0.43561672159709813
# Validation rmse for 2th set is 0.4365607300283961
# current learning rate 0.001059753590486383
# Training epoch 0 took 6.701s
# Validation rmse for 3th set 0 epoch is 0.4464858342322001
# current learning rate 0.00025251901896782393
# Training epoch 1 took 6.566s
# Validation rmse for 3th set 1 epoch is 0.43805102531399887
# current learning rate 7.385825868704096e-05
# Training epoch 2 took 6.560s
# Validation rmse for 3th set 2 epoch is 0.4359684938886514
# Validation rmse for 3th set is 0.43704734194603895
# Overall Validation rmse for [255, 70, 234, 170, 460, 234, 0.001059753590486383, 0.00025251901896782393, 7.385825868704096e-05, 0.2953066873983904, 0.0010503063647482136, 0.0005017440656326867, 26, 24, 20, 21, 4003] is 0.4370525428079088
#
#
# current learning rate 0.00103842702786734
# Training epoch 0 took 13.126s
# Validation rmse for 0th set 0 epoch is 0.44357091324544806
# current learning rate 0.0005683808869267143
# Training epoch 1 took 13.216s
# Validation rmse for 0th set 1 epoch is 0.43360161737581115
# current learning rate 4.16843340301095e-05
# Training epoch 2 took 13.096s
# Validation rmse for 0th set 2 epoch is 0.432033252914606
# Validation rmse for 0th set is 0.43246846130713995
# current learning rate 0.00103842702786734
# Training epoch 0 took 13.193s
# Validation rmse for 1th set 0 epoch is 0.4439901002683947
# current learning rate 0.0005683808869267143
# Training epoch 1 took 13.200s
# Validation rmse for 1th set 1 epoch is 0.4347529611750873
# current learning rate 4.16843340301095e-05
# Training epoch 2 took 13.133s
# Validation rmse for 1th set 2 epoch is 0.431939374860259
# Validation rmse for 1th set is 0.43268724345678455
# current learning rate 0.00103842702786734
# Training epoch 0 took 13.130s
# Validation rmse for 2th set 0 epoch is 0.444114734171861
# current learning rate 0.0005683808869267143
# Training epoch 1 took 13.110s
# Validation rmse for 2th set 1 epoch is 0.433489124275547
# current learning rate 4.16843340301095e-05
# Training epoch 2 took 13.112s
# Validation rmse for 2th set 2 epoch is 0.4319341860459112
# Validation rmse for 2th set is 0.43255981355494677
# current learning rate 0.00103842702786734
# Training epoch 0 took 13.199s
# Validation rmse for 3th set 0 epoch is 0.44575764836992915
# current learning rate 0.0005683808869267143
# Training epoch 1 took 13.128s
# Validation rmse for 3th set 1 epoch is 0.4348888732515758
# current learning rate 4.16843340301095e-05
# Training epoch 2 took 13.114s
# Validation rmse for 3th set 2 epoch is 0.43308778330387676
# Validation rmse for 3th set is 0.4337777319809715
# Overall Validation rmse for [349, 512, 177, 47, 284, 96, 0.00103842702786734, 0.0005683808869267143, 4.16843340301095e-05, 0.04474219392653993, 0.196226955309194, 0.0015755523817305886, 30, 14, 30, 16, 2918] is 0.4328736344884156
#
#
# current learning rate 0.006009103429702446
# Training epoch 0 took 12.921s
# Validation rmse for 0th set 0 epoch is 0.43123927241417886
# current learning rate 0.0004758082932059917
# Training epoch 1 took 12.918s
# Validation rmse for 0th set 1 epoch is 0.42232147290192346
# current learning rate 7.421168404280841e-05
# Training epoch 2 took 12.849s
# Validation rmse for 0th set 2 epoch is 0.4217221019498492
# Validation rmse for 0th set is 0.4219621323361677
# current learning rate 0.006009103429702446
# Training epoch 0 took 12.836s
# Validation rmse for 1th set 0 epoch is 0.4334470709507868
# current learning rate 0.0004758082932059917
# Training epoch 1 took 12.905s
# Validation rmse for 1th set 1 epoch is 0.4227568035464058
# current learning rate 7.421168404280841e-05
# Training epoch 2 took 12.922s
# Validation rmse for 1th set 2 epoch is 0.4221924955991184
# Validation rmse for 1th set is 0.4225672199973358
# current learning rate 0.006009103429702446
# Training epoch 0 took 12.898s
# Validation rmse for 2th set 0 epoch is 0.4316579915877126
# current learning rate 0.0004758082932059917
# Training epoch 1 took 12.790s
# Validation rmse for 2th set 1 epoch is 0.42250510308445527
# current learning rate 7.421168404280841e-05
# Training epoch 2 took 12.789s
# Validation rmse for 2th set 2 epoch is 0.42128831505325426
# Validation rmse for 2th set is 0.42182069519415316
# current learning rate 0.006009103429702446
# Training epoch 0 took 12.765s
# Validation rmse for 3th set 0 epoch is 0.43354460349052587
# current learning rate 0.0004758082932059917
# Training epoch 1 took 12.863s
# Validation rmse for 3th set 1 epoch is 0.4242148202909194
# current learning rate 7.421168404280841e-05
# Training epoch 2 took 12.993s
# Validation rmse for 3th set 2 epoch is 0.42362943468445885
# Validation rmse for 3th set is 0.4238756505186822
# Overall Validation rmse for [67, 424, 56, 125, 73, 79, 0.006009103429702446, 0.0004758082932059917, 7.421168404280841e-05, 0.13555613688939325, 0.31617615114231157, 0.0005208531095785397, 30, 25, 17, 22, 1519] is 0.42255720397914087

# %%
#0.413 -- [244, 245, 20, 30, 379, 111, 0.007, 0.004889124444379768, 0.0008893344484252365, 0.20170778812902923, 0.4322101218941912, 0.00040881437786467474, 22, 14, 29, 15, 700]
#0.4125 - [335, 368, 30, 207, 501, 129, 0.0028, 0.0007076168437656144, 4.778300593129668e-05, 0.32388425803846765, 0.09060816640189791, 0.0006894953854488185, 27, 26, 18, 27, 396]
#0.4128 - [230, 478, 19, 50, 350, 156, 0.0088, 0.00451485158454785, 0.0003698907526454667, 0.00413597314173117, 0.06832928809863183, 0.0006335617241631399, 10, 30, 15, 30, 797]
#0.4129 - [249, 357, 48, 209, 331, 252, 0.0029, 0.0015495505982415813, 0.00018267824518215857, 0.3003165566092163, 0.23796727279121543, 0.00048365710299387864, 28, 30, 11, 18, 962]
#0.4131 - [422, 322, 252, 115, 425, 190, 0.0037, 0.001963948456452917, 3.8822104969446264e-05, 0.009805955801694414, 0.03824395410569333, 0.0007812555233795872, 10, 14, 14, 27, 768]
#0.4131 - [312, 412, 195, 82, 299, 193, 0.0050, 0.003602751160806771, 8.203542652197838e-05, 0.0031397184953593266, 0.057066240447346026, 0.00012511895820388477, 22, 19, 15, 29, 569]
#0.4132 - [215, 268, 172, 17, 251, 246, 0.0034, 0.002967759775499689, 0.0005524896190267775, 0.2209409030480764, 0.29145797592055195, 0.0011499201495264347, 21, 15, 14, 21, 281]
#0.4124 - [133, 197, 16, 36, 452, 97, 0.0043, 0.0025318236697005393, 4.498909382519441e-05, 0.15558319249405014, 0.0544129578491453, 4.571395252885303e-05, 25, 15, 18, 26, 439]
#0.4108 - [347, 291, 19, 141, 438, 185, 0.0030, 0.0020955705392677877, 0.0006309101781639358, 0.08444600645130546, 0.0721869479739259, 0.0006316700578813118, 29, 10, 16, 12, 1285]
#0.4123 - [288, 290, 220, 182, 458, 143, 0.0016, 0.0004175825175008739, 3.430748111600067e-05, 0.0033717035103933055, 0.031262832742402324, 0.00026036277618005646, 19, 13, 10, 16, 329]
#0.4108 - [132, 407, 94, 249, 437, 156, 0.0040, 0.0013121365325581096, 0.0004805886736155402, 0.005072081019905154, 0.014233366406514063, 0.0001552363639330923, 29, 14, 18, 15, 579]
#0.4131 - [433, 380, 179, 73, 508, 193, 0.0043, 0.004799784588296129, 0.0008674740857502088, 0.1639507990732214, 0.05043616270685462, 0.0012438307389190054, 27, 21, 12, 30, 2071]
# Out:
# 0.4071720483590182

# %%
np.sqrt(metrics.mean_squared_error(y_true_val[np.abs(y_true_val- y_pred_val) <= 1.5], y_pred_val[np.abs(y_true_val- y_pred_val) <= 1.5]))
# Out:
# 0.39042055713946605

# %%
df_train.iloc[val_idx].loc[np.abs(y_true_val- y_pred_val) > 1.5].category_name.value_counts()
# Out:
# women women/jewelry women/jewelry/bracelets                                                                  6
# other other/other other/other/other                                                                          5
# women women/athleticapparel women/athleticapparel/pants,tights,leggings                                      5
# women women/women'shandbags women/women'shandbags/shoulderbag                                                4
# vintage&collectibles vintage&collectibles/tradingcards vintage&collectibles/tradingcards/animation           4
# beauty beauty/makeup beauty/makeup/nails                                                                     3
# women women/other women/other/other                                                                          3
# vintage&collectibles vintage&collectibles/tradingcards vintage&collectibles/tradingcards/sports              3
# kids kids/toys kids/toys/games                                                                               3
# women women/jewelry women/jewelry/necklaces                                                                  3
# electronics electronics/cellphones&accessories electronics/cellphones&accessories/cellphoneaccessories       2
# women women/tops&blouses women/tops&blouses/t-shirts                                                         2
# women women/tops&blouses women/tops&blouses/blouse                                                           2
# kids kids/toys kids/toys/buildingtoys                                                                        2
# beauty beauty/skincare beauty/skincare/face                                                                  2
# home home/homedécor home/homedécor/homedécoraccents                                                          2
# vintage&collectibles vintage&collectibles/toy vintage&collectibles/toy/actionfigure                          2
# women women/jewelry women/jewelry/rings                                                                      2
# unk_cat                                                                                                      2
# electronics electronics/videogames&consoles electronics/videogames&consoles/games                            2
# beauty beauty/makeup beauty/makeup/face                                                                      2
# women women/underwear women/underwear/panties                                                                2
# home home/other home/other/other                                                                             2
# women women/women'shandbags women/women'shandbags/messenger&crossbody                                        2
# beauty beauty/makeup beauty/makeup/lips                                                                      2
# vintage&collectibles vintage&collectibles/book vintage&collectibles/book/comics                              2
# vintage&collectibles vintage&collectibles/jewelry vintage&collectibles/jewelry/other                         1
# electronics electronics/tv,audio&surveillance electronics/tv,audio&surveillance/other                        1
# women women/women'saccessories women/women'saccessories/watches                                              1
# other other/automotive other/automotive/performanceparts&accessories                                         1
#                                                                                                             ..
# electronics electronics/tv,audio&surveillance electronics/tv,audio&surveillance/portableaudio&accessories    1
# kids kids/toys kids/toys/dolls&accessories                                                                   1
# handmade handmade/accessories handmade/accessories/charm                                                     1
# women women/women'saccessories women/women'saccessories/sunglasses                                           1
# electronics electronics/videogames&consoles electronics/videogames&consoles/accessories                      1
# women women/coats&jackets women/coats&jackets/other                                                          1
# other other/musicalinstruments other/musicalinstruments/guitars                                              1
# electronics electronics/cameras&photography electronics/cameras&photography/digitalcameras                   1
# electronics electronics/cameras&photography electronics/cameras&photography/lenses&filters                   1
# vintage&collectibles vintage&collectibles/tradingcards vintage&collectibles/tradingcards/sci-fi,fantasy      1
# vintage&collectibles vintage&collectibles/collectibles vintage&collectibles/collectibles/glass               1
# men men/men'saccessories men/men'saccessories/backpacks,bags&briefcases                                      1
# women women/athleticapparel women/athleticapparel/shirts&tops                                                1
# women women/jeans women/jeans/slim,skinny                                                                    1
# sports&outdoors sports&outdoors/exercise sports&outdoors/exercise/other                                      1
# home home/bedding home/bedding/quilts                                                                        1
# beauty beauty/fragrance beauty/fragrance/women                                                               1
# beauty beauty/fragrance beauty/fragrance/men                                                                 1
# electronics electronics/videogames&consoles electronics/videogames&consoles/videogamingmerchandise           1
# kids kids/gear kids/gear/backpacks&carriers                                                                  1
# handmade handmade/accessories handmade/accessories/hair                                                      1
# men men/men'saccessories men/men'saccessories/watches                                                        1
# handmade handmade/papergoods handmade/papergoods/sticker                                                     1
# handmade handmade/music handmade/music/vinyl                                                                 1
# women women/women'saccessories women/women'saccessories/wallets                                              1
# women women/skirts women/skirts/maxi                                                                         1
# home home/homedécor home/homedécor/tapestries                                                                1
# electronics electronics/other electronics/other/other                                                        1
# women women/women'saccessories women/women'saccessories/hairaccessories                                      1
# vintage&collectibles vintage&collectibles/electronics vintage&collectibles/electronics/videogame             1
# Name: category_name, Length: 88, dtype: int64

# %%
tmp = df_train.iloc[val_idx].loc[np.abs(y_true_val- y_pred_val) > 1.5]
tmp['price'] = np.expm1(y_true_val[np.abs(y_true_val- y_pred_val) > 1.5])
tmp['predicted'] = np.expm1(y_pred_val[np.abs(y_true_val- y_pred_val) > 1.5])

# %%
tmp.loc[tmp.category_name.str.contains('bracelets')]
# Out:
#          train_id                                      name  \
# 694691     695063  100% authentic bizentine design 14k gold
# 996274     996837             Breast Cancer Awareness Charm
# 326686     326840      James Avery 925 18 8" Charm bracelet
# 1458255   1459112                AUTHENTIC DY rope bracelet
# 917666     918175                     Bundle of 3 bracelets
# 1365943   1366738                    Keep collective charms
#
#          item_condition_id                                category_name  \
# 694691                   3  women women/jewelry women/jewelry/bracelets
# 996274                   2  women women/jewelry women/jewelry/bracelets
# 326686                   3  women women/jewelry women/jewelry/bracelets
# 1458255                  3  women women/jewelry women/jewelry/bracelets
# 917666                   2  women women/jewelry women/jewelry/bracelets
# 1365943                  2  women women/jewelry women/jewelry/bracelets
#
#            brand_name  shipping  \
# 694691      unk_brand         1
# 996274      unk_brand         0
# 326686      unk_brand         0
# 1458255  david_yurman         1
# 917666      unk_brand         0
# 1365943     unk_brand         1
#
#                                           item_description  price   predicted
# 694691                                  No description yet  300.0   62.547579
# 996274                                  No description yet   50.0    8.626883
# 326686   Guaranteed authentic, priced to sell. No offer...  506.0   95.802142
# 1458255        Black rope bracelet for smaller wrist 6.5".   40.0  273.346336
# 917666                              3 bracelets for Lorena   64.0   10.449836
# 1365943  Note: lot is as pictured, minus one purple/pin...  100.0   15.740973

# %%
#playstation vr -- as a single word
# category games - controller and adapters
# integers before
